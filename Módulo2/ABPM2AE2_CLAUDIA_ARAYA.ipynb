# %%
import pandas as pd

# %% [markdown]
# 3. Escribir una función que reciba un diccionario con las notas de los
# alumnos en curso en un examen y devuelva una serie con las notas de
# los alumnos aprobados ordenadas de mayor a menor.

# %%
def notas(nota):
  nota = pd.Series(nota) #convierte el diccionario en serie
  return nota[nota>=4].sort_values(ascending=False) #alumno aprueba con nota 4, ordene la serie de mayor a menor tomando las notas >= a 4

nota = {'Alumno 1': 7, 'Alumno 2': 4, 'Alumno 3': 5, 'Alumno 4': 2} #diccionario con las notas
print(notas(nota))
# Out:
# Alumno 1    7
# Alumno 3    5
# Alumno 2    4
# dtype: int64

# %% [markdown]
# 4. Escribir programa que genere y muestre por pantalla un DataFrame
# con los datos de la tabla siguiente:
#
# ![image.png](data:image/png;base64,...)

# %%
data = {'Mes': ['Enero','Febrero','Marzo','Abril'],
        'Ventas': [30500, 35600, 28300, 33900],
        'Gastos': [22000, 23400, 18100, 20700]}
display(pd.DataFrame(data))
# Out:
#        Mes  Ventas  Gastos
# 0    Enero   30500   22000
# 1  Febrero   35600   23400
# 2    Marzo   28300   18100
# 3    Abril   33900   20700

# %% [markdown]
# 5. Convertir un diccionario Python en un objeto Series:
#
# ![image.png](data:image/png;base64,...)

# %%
datos = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
serie = pd.Series(datos) #convierte un diccionario en serie
serie
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# 6. Obtener una columna de un objeto DataFrame como un objeto Series.
#
#  ![image.png](data:image/png;base64,...)

# %%
datos = {'A': [1,2,3,4,5], 'B': [9,8,7,6,5], 'C': [2,3,5,7,11]}

df = pd.DataFrame(data=datos) #crea un dataframe del diccionario datos
df
# Out:
#    A  B   C
# 0  1  9   2
# 1  2  8   3
# 2  3  7   5
# 3  4  6   7
# 4  5  5  11

# %% [markdown]
# 7. Ordenar los valores de un objeto Series.
#
# ![image.png](data:image/png;base64,...)

# %%
datos = ['1.1', 'Python', '0.5', 'pandas', '2.8']

display(pd.Series(datos).sort_values()) #sort_values() ordena los valores de la serie
# Out:
# 2       0.5
# 0       1.1
# 4       2.8
# 1    Python
# 3    pandas
# dtype: object
