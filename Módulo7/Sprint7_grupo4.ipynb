# %% [markdown]
# **Grupo 4**
#
# * Alex Riquelme
# * Camila Aguilar
# * Camila Varas
# * Fabian Cuevas
# * Claudia Araya

# %% [markdown]
# #1 cargar libreria

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #2 carga data

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes-data.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# # 3.define el modelo Keras

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #4.compila Keras

# %%
# compilar
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # 5.entrena el modelo

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 3ms/step - loss: 9.3248 - accuracy: 0.4180
# Epoch 2/150
# 77/77 [==============================] - 0s 3ms/step - loss: 2.0405 - accuracy: 0.5443
# Epoch 3/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.9052 - accuracy: 0.6289
# Epoch 4/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8273 - accuracy: 0.6315
# Epoch 5/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8025 - accuracy: 0.6263
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7451 - accuracy: 0.6315
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7055 - accuracy: 0.6445
# Epoch 8/150
# 77/77 [==============================] - 0s 3ms/step - loss: 0.6913 - accuracy: 0.6458
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6681 - accuracy: 0.6484
# Epoch 10/150
# ...

# %% [markdown]
# # 6.Evalua el modelo Keras

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.7708
# Accuracy: 77.08

# %% [markdown]
# # 7.Une todo el conjunto de datos en la red neuronal

# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# carga el data set
dataset = loadtxt('pima-indians-diabetes-data.csv', delimiter=',')
# fragmenta como input (X) y  output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# se define el modelo keras
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compila el modelo keras
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 2ms/step - loss: 4.3440 - accuracy: 0.5885
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.4610 - accuracy: 0.5742
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.0148 - accuracy: 0.6406
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8596 - accuracy: 0.6641
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7788 - accuracy: 0.6641
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.6549
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7219 - accuracy: 0.6576
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6904 - accuracy: 0.6706
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7019 - accuracy: 0.6641
# Epoch 10/150
# ...

# %% [markdown]
# # 8. Predicciones

# %%
# realiza la probabilidad de predicciones del modelo
predictions = model.predict(X)
# redondea las predicciones
rounded = [round(x[0]) for x in predictions]
# Out:
# 24/24 [==============================] - 0s 1ms/step

# %% [markdown]
# alternativa de predicciòn con probabilidad entre 0 y 1

# %%
# hace la clase de predicciones
predictions = (model.predict(X) > 0.5).astype(int)
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %%
# primera red neuronal con keras para realizar la prediccion
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# load the dataset
dataset = loadtxt('pima-indians-diabetes-data.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10, verbose=0)
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
    print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i][0], y[i]))
# Out:
# 24/24 [==============================] - 0s 2ms/step
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)

# %% [markdown]
# Una vez ajustado el modelo, se realizan predicciones para todos los ejemplos del conjunto de datos, y se imprimen las filas de entrada y el valor de clase predicho para los cinco primeros ejemplos y se comparan con el valor de clase esperado.
#
# Puede ver que la mayoría de las filas se predicen correctamente. De hecho, puede esperar que alrededor del 76,04% de las filas se predigan correctamente basándose en el rendimiento estimado del modelo en la sección anterior.
